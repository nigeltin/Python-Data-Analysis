# %%
import pandas as pd

# %%
chicago = pd.read_csv('chicago.csv').dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago.head(3)
# Out:
#                 Name    Position Title   Department Employee Annual Salary
# 0    AARON,  ELVIA J  WATER RATE TAKER  WATER MGMNT              $90744.00
# 1  AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# 2     AARON,  KARINA    POLICE OFFICER       POLICE              $84450.00

# %%
chicago.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32062 entries, 0 to 32061
# Data columns (total 4 columns):
# Name                      32062 non-null object
# Position Title            32062 non-null object
# Department                32062 non-null category
# Employee Annual Salary    32062 non-null object
# dtypes: category(1), object(3)
# memory usage: 1.0+ MB

# %%
chicago['Department'].nunique()
# Out:
# 35

# %%
#changing to a data type that takes less memory
chicago['Department'] = chicago['Department'].astype('category')

# %%
#Using lower(), upper(), title(), len()

'LIVERPOOL'.lower()
# Out:
# 'liverpool'

# %%
'sterling'.upper()
# Out:
# 'STERLING'

# %%
'sterling'.title()
# Out:
# 'Sterling'

# %%
len('Man City') #spaces count
# Out:
# 8

# %%
chicago['Name'].str.title() #prefix with .str when applying to a cloumn
# Out:
# 0                 Aaron,  Elvia J
# 1               Aaron,  Jeffery M
# 2                  Aaron,  Karina
# 3             Aaron,  Kimberlei R
# 4             Abad Jr,  Vicente M
# 5                 Abarca,  Anabel
# 6               Abarca,  Emmanuel
# 7               Abascal,  Reece E
# 8            Abbasi,  Christopher
# 9           Abbatacola,  Robert J
# 10          Abbatemarco,  James J
# 11               Abbate,  Terry M
# 12               Abbott,  Betty L
# 13              Abbott,  Lynise M
# 14         Abbruzzese,  William J
# 15                Abdallah,  Zaid
# 16          Abdelhadi,  Abdalmahd
# 17            Abdellatif,  Aref R
# 18             Abdelmajeid,  Aziz
# 19            Abdollahzadeh,  Ali
# 20       Abdul-Karim,  Muhammad A
# 21            Abdullah,  Daniel N
# 22               Abdullah,  Kevin
# 23           Abdullah,  Lakenya N
# 24            Abdullah,  Rashad J
# 25           Abdulsattar,  Mudhar
# 26           Abdul-Shakur,  Tahir
# ...

# %%
chicago['Department'].str.len()
# Out:
# 0        11
# 1         6
# 2         6
# 3        16
# 4        11
# 5        12
# 6        13
# 7         4
# 8        12
# 9         8
# 10        4
# 11        6
# 12       16
# 13        6
# 14        4
# 15        6
# 16        6
# 17        4
# 18        6
# 19        4
# 20       11
# 21        4
# 22        4
# 23        4
# 24       16
# 25       11
# 26       13
# 27       16
# 28        6
# 29        4
#          ..
# 32032    16
# 32033     6
# 32034     6
# 32035     6
# 32036    13
# 32037     4
# 32038    11
# 32039     4
# 32040     6
# 32041     4
# 32042    16
# 32043    13
# 32044     6
# 32045     4
# 32046     7
# 32047     6
# 32048     3
# 32049     4
# 32050    11
# 32051     8
# 32052     6
# 32053     4
# 32054     6
# 32055     6
# 32056    16
# 32057    16
# 32058     6
# 32059     6
# 32060     6
# 32061     4
# Name: Department, Length: 32062, dtype: int64

# %%
'Man City'.replace('y', 'eh')
# Out:
# 'Man Citeh'

# %%
chicago.tail(3)
# Out:
#                       Name           Position Title Department  \
# 32059    ZYMANTAS,  MARK E           POLICE OFFICER     POLICE
# 32060  ZYRKOWSKI,  CARLO E           POLICE OFFICER     POLICE
# 32061  ZYSKOWSKI,  DARIUSZ  CHIEF DATA BASE ANALYST       DoIT
#
#       Employee Annual Salary
# 32059              $84450.00
# 32060              $87384.00
# 32061             $113664.00

# %%
chicago['Department'] = chicago['Department'].str.replace('MGMNT', 'MANAGEMENT')

# %%
chicago['Employee Annual Salary'] = chicago['Employee Annual Salary'].str.replace('$', '').astype(float)

# %%
chicago['Employee Annual Salary'].nlargest(5)
# Out:
# 8184     300000.0
# 7954     216210.0
# 25532    202728.0
# 8924     197736.0
# 8042     197724.0
# Name: Employee Annual Salary, dtype: float64

# %%
water = chicago['Position Title'].str.lower().str.contains('water')
chicago[water]
# Out:
#                           Name                                 Position Title  \
# 0              AARON,  ELVIA J                               WATER RATE TAKER
# 554         ALUISE,  VINCENT G             FOREMAN OF WATER PIPE CONSTRUCTION
# 671            ANDER,  PERRY A                               WATER CHEMIST II
# 685        ANDERSON,  ANDREW J  DISTRICT SUPERINTENDENT OF WATER DISTRIBUTION
# 702          ANDERSON,  DONALD             FOREMAN OF WATER PIPE CONSTRUCTION
# 1054          ASHLEY,  KARMA T                               WATER CHEMIST II
# 1079         ATKINS,  JOANNA M                               WATER CHEMIST II
# 1181        AZEEM,  MOHAMMED A                               WATER CHEMIST II
# 1285            BAJIC,  JOHN A                          WATER METER MACHINIST
# 2400          BOLTON,  BRIAN E                               WATER RATE TAKER
# 2586           BOYCE,  ADNER L                               WATER CHEMIST II
# ...

# %%
chicago[chicago['Position Title'].str.lower().str.startswith('water')]
# Out:
#                           Name               Position Title        Department  \
# 0              AARON,  ELVIA J             WATER RATE TAKER  WATER MANAGEMENT
# 671            ANDER,  PERRY A             WATER CHEMIST II  WATER MANAGEMENT
# 1054          ASHLEY,  KARMA T             WATER CHEMIST II  WATER MANAGEMENT
# 1079         ATKINS,  JOANNA M             WATER CHEMIST II  WATER MANAGEMENT
# 1181        AZEEM,  MOHAMMED A             WATER CHEMIST II  WATER MANAGEMENT
# 1285            BAJIC,  JOHN A        WATER METER MACHINIST  WATER MANAGEMENT
# 2400          BOLTON,  BRIAN E             WATER RATE TAKER  WATER MANAGEMENT
# 2586           BOYCE,  ADNER L             WATER CHEMIST II  WATER MANAGEMENT
# 2745          BRANDYS,  DANIEL             WATER CHEMIST II  WATER MANAGEMENT
# 3143          BROWN,  SHARON L             WATER RATE TAKER  WATER MANAGEMENT
# 3246      BUCHANAN,  ANTHONY L             WATER CHEMIST II  WATER MANAGEMENT
# ...

# %%
chicago[chicago['Position Title'].str.lower().str.endswith('ist')]
# Out:
#                           Name                          Position Title  \
# 184             AFROZ,  NAYYAR                            PSYCHIATRIST
# 308           ALARCON,  LUIS J              LOAN PROCESSING SPECIALIST
# 422           ALLAIN,  CAROLYN    SENIOR TELECOMMUNICATIONS SPECIALIST
# 472             ALLEN,  ROBERT                               MACHINIST
# 705        ANDERSON,  EDWARD M               SR PROCUREMENT SPECIALIST
# 1022            ARTEAGA,  PAUL                               MACHINIST
# 1163           AYALA JR,  JUAN             FIELD SANITATION SPECIALIST
# 1285            BAJIC,  JOHN A                   WATER METER MACHINIST
# 1558       BARRETT,  BARBARA J           TECHNICAL TRAINING SPECIALIST
# 1869        BELTRAN,  MAURICIO                  PROCUREMENT SPECIALIST
# 2095        BIGGANE,  THOMAS M                     SECURITY SPECIALIST
# 2319            BOBBA,  MAHITA              GRANTS RESEARCH SPECIALIST
# ...

# %%
#removing spaces
'    Raheem Sterling '.lstrip()  #removes spaces on the left
# Out:
# 'Raheem Sterling '

# %%
'    Raheem Sterling '.rstrip() #removes spaces on the right
# Out:
# '    Raheem Sterling'

# %%
'    Raheem Sterling '.strip() #removes every space on the ends
# Out:
# 'Raheem Sterling'

# %%
chicago['Name'] = chicago['Name'].str.rstrip().str.lstrip()

# %%
chicago['Position Title'] = chicago['Position Title'].str.strip()

# %%
chicago = pd.read_csv('chicago.csv', index_col = 'Name').dropna(how='all')
chicago['Department'] = chicago['Department'].astype('category')
chicago.head(3)
# Out:
#                      Position Title   Department Employee Annual Salary
# Name
# AARON,  ELVIA J    WATER RATE TAKER  WATER MGMNT              $90744.00
# AARON,  JEFFERY M    POLICE OFFICER       POLICE              $84450.00
# AARON,  KARINA       POLICE OFFICER       POLICE              $84450.00

# %%
chicago.index = chicago.index.str.strip().str.title()
# Out:
# Index(['Aaron,  Elvia J', 'Aaron,  Jeffery M', 'Aaron,  Karina',
#        'Aaron,  Kimberlei R', 'Abad Jr,  Vicente M', 'Abarca,  Anabel',
#        'Abarca,  Emmanuel', 'Abascal,  Reece E', 'Abbasi,  Christopher',
#        'Abbatacola,  Robert J',
#        ...
#        'Zwit,  Jeffrey J', 'Zwolfer,  Matthew W', 'Zych,  Mateusz',
#        'Zydek,  Bryan', 'Zygadlo,  John P', 'Zygadlo,  Michael J',
#        'Zygowicz,  Peter J', 'Zymantas,  Mark E', 'Zyrkowski,  Carlo E',
#        'Zyskowski,  Dariusz'],
#       dtype='object', name='Name', length=32062)

# %%
chicago.columns = chicago.columns.str.upper()

# %%
'Raheem Sterling is top of the league'.split(' ')
# Out:
# ['Raheem', 'Sterling', 'is', 'top', 'of', 'the', 'league']

# %%
chicago.index.str.split(',').str.get(0).str.title().value_counts()
# Out:
# Williams           293
# Johnson            244
# Smith              241
# Brown              185
# Jones              183
# Rodriguez          171
# Jackson            136
# Garcia             130
# Davis              127
# Hernandez          110
# Martinez           108
# Lopez              106
# Gonzalez           104
# Perez              100
# Wilson              94
# Rivera              90
# Thomas              89
# Anderson            82
# Torres              81
# Murphy              80
# Robinson            79
# Moore               78
# Sanchez             76
# Harris              76
# Miller              75
# Lewis               74
# Taylor              73
# Martin              72
# Clark               66
# White               66
#                   ...
# Gulley               1
# Lumpkin Inglam       1
# Ryczek               1
# Levigne              1
# Miller Campbell      1
# Galbraith            1
# Faber                1
# Hodrick              1
# Bargo                1
# ...

# %%
chicago['POSITION TITLE'].str.split(' ').str.get(0)
# Out:
# Name
# AARON,  ELVIA J                             WATER
# AARON,  JEFFERY M                          POLICE
# AARON,  KARINA                             POLICE
# AARON,  KIMBERLEI R                         CHIEF
# ABAD JR,  VICENTE M                         CIVIL
# ABARCA,  ANABEL                              ASST
# ABARCA,  EMMANUEL                         GENERAL
# ABASCAL,  REECE E                         TRAFFIC
# ABBASI,  CHRISTOPHER                        STAFF
# ABBATACOLA,  ROBERT J                  ELECTRICAL
# ABBATEMARCO,  JAMES J                        FIRE
# ABBATE,  TERRY M                           POLICE
# ABBOTT,  BETTY L                           FOSTER
# ABBOTT,  LYNISE M                           CLERK
# ABBRUZZESE,  WILLIAM J               INVESTIGATOR
# ABDALLAH,  ZAID                            POLICE
# ABDELHADI,  ABDALMAHD                      POLICE
# ABDELLATIF,  AREF R                   FIREFIGHTER
# ABDELMAJEID,  AZIZ                         POLICE
# ...
